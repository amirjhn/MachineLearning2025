# %% [markdown]
# **Problem 1:** Create a NumPy array of 20 random integers between 1 and 100. Calculate the mean, median, and standard deviation of the array.

# %%
import numpy as np
arr = np.random.randint(1,100,20)
print("array is :", arr)
print("mean is :", np.mean(arr))
print("median is :", np.median(arr))
print("standard deviation is :", np.std(arr))
# Out:
# array is : [13 22 85 54 63 48 83 59 11 72 50 82 61 13 96 49 40 58 39 47]
# mean is : 52.25
# median is : 52.0
# standard deviation is : 24.047609028757932

# %% [markdown]
# **Problem 2:** Create a Pandas DataFrame with three columns - 'Name', 'Age', and 'City' - and at least five rows of data. Perform a basic data exploration by displaying the first 3 rows, the last 2 rows, and a summary of statistics for the 'Age' column.

# %%
import pandas as pd
data = {
    "Name": ["Amir","Ali","Sara","Navid","Leyla"],
    "Age": [22, 19, 20, 30, 21],
    "City": ["Tabriz","Esfahan","Tehran","Karaj","Shiraz"]

}
df = pd.DataFrame(data)
print("first 3 rows is :")
print(df.head(3))
print("\nlast 2 rows is :")
print(df.tail(2))
print("\na summary of statistics for the Age is :")
print(df["Age"].describe())
# Out:
# first 3 rows is :
#    Name  Age     City
# 0  Amir   22   Tabriz
# 1   Ali   19  Esfahan
# 2  Sara   20   Tehran
#
# last 2 rows is :
#     Name  Age    City
# 3  Navid   30   Karaj
# 4  Leyla   21  Shiraz
#
# a summary of statistics for the Age is :
# count     5.000000
# mean     22.400000
# std       4.393177
# min      19.000000
# 25%      20.000000
# 50%      21.000000
# 75%      22.000000
# max      30.000000
# Name: Age, dtype: float64

# %% [markdown]
# **Problem 3:** Create a bar chart using Matplotlib to visualize the following data: Monthly sales for a store (January to May). Use appropriate labels and titles for the chart.

# %%
import numpy as np
import matplotlib.pyplot as plt
lables = ["january","fabruary","march","april","may"]
values = np.random.randint(1000,10000,5)
plt.bar(lables,values)
plt.xlabel("month")
plt.ylabel("sales")
plt.title("Monthly sales for a store (January to May)")
# Out:
# Text(0.5, 1.0, 'Monthly sales for a store (January to May)')

# %% [markdown]
# **Problem 4:** Create two NumPy arrays, 'arr1' and 'arr2', both of size 5x5 with random integer values. Perform element-wise addition, subtraction, multiplication, and division between the two arrays.

# %%
import numpy as np
array = np.random.randint(1,100,50).reshape(2,5,5)
arr1 = array[0,:,:]
arr2 = array[1,:,:]
print("array 1 is :\n", arr1)
print("array 2 is :\n", arr2)
print("addition is :\n", arr1 + arr2)
print("subtraction is :\n", arr1 - arr2)
print("multiplication is :\n", arr1 * arr2)
print("division is :\n", arr1 / arr2)
# Out:
# array 1 is :
#  [[28 39 10 90 43]
#  [27  8 74 49 56]
#  [53 65 62 68 33]
#  [24 17 52 80 95]
#  [94 97 37 63 34]]
# array 2 is :
#  [[68 33 49 54 18]
#  [84 56 55 52 32]
#  [55 80 12 23 44]
#  [62 46 34 53 57]
#  [ 7 15  3 66 93]]
# addition is :
#  [[ 96  72  59 144  61]
#  [111  64 129 101  88]
#  [108 145  74  91  77]
#  [ 86  63  86 133 152]
#  [101 112  40 129 127]]
# subtraction is :
#  [[-40   6 -39  36  25]
#  [-57 -48  19  -3  24]
#  [ -2 -15  50  45 -11]
#  [-38 -29  18  27  38]
#  [ 87  82  34  -3 -59]]
# multiplication is :
#  [[1904 1287  490 4860  774]
#  [2268  448 4070 2548 1792]
#  [2915 5200  744 1564 1452]
#  [1488  782 1768 4240 5415]
#  [ 658 1455  111 4158 3162]]
# division is :
#  [[ 0.41176471  1.18181818  0.20408163  1.66666667  2.38888889]
#  [ 0.32142857  0.14285714  1.34545455  0.94230769  1.75      ]
#  [ 0.96363636  0.8125      5.16666667  2.95652174  0.75      ]
#  [ 0.38709677  0.36956522  1.52941176  1.50943396  1.66666667]
#  [13.42857143  6.46666667 12.33333333  0.95454545  0.3655914 ]]

# %% [markdown]
# **Problem 5:** Given a Pandas DataFrame with information about employees, filter and display only the employees who are older than 30 years.

# %%
import pandas as pd
data ={
    "Name":["Amir","Ali","Leyla","Sara","Sana"],
    "Age":[35,21,43,18,30]
}
df = pd.DataFrame(data)
print("the employees who are older than 30 years:")
print(df[df["Age"]>30])
# Out:
# the employees who are older than 30 years:
#     Name  Age
# 0   Amir   35
# 2  Leyla   43

# %% [markdown]
# **Problem 6:** Create a scatter plot using Matplotlib to visualize a dataset of 100 random (x, y) coordinates. Label the axes appropriately and give the plot a title.

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.random.rand(100)
y = np.random.rand(100)

plt.scatter(x, y, label="random points")
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot of Random Points')
plt.legend()

# %% [markdown]
# **Problem 7:** Create two NumPy matrices, 'matrix1' (2x3) and 'matrix2' (3x4), with random values. Perform matrix multiplication between the two matrices.

# %%
import numpy as np
arr1 = np.random.randint(1,100,6)
arr2 = np.random.randint(1,100,12)
matrix1 = arr1.reshape(2,3)
matrix2 = arr2.reshape(3,4)
multiplication = matrix1 @ matrix2

print("matrix 1 is :\n", matrix1)
print("matrix 2 is :\n", matrix2)
print("matrix multiplication is :\n", multiplication)

# or we can use:
# multiplication = np.matmul(matrix1,matrix2)
# Out:
# matrix 1 is :
#  [[97 38 46]
#  [17 73 60]]
# matrix 2 is :
#  [[ 7  6 49 59]
#  [64 80 92  6]
#  [75 20 90 40]]
# matrix multiplication is :
#  [[ 6561  4542 12389  7791]
#  [ 9291  7142 12949  3841]]

# %% [markdown]
# **Problem 8:** Given a Pandas DataFrame containing sales data, calculate and display the total sales for each product category.

# %%
import pandas as pd
data = {
    "product":["A1","A2","A3","A4","A2","A3","A1"],
    "category":["B1","B2","B3","B4","B2","B3","B1"],
    "sale":[200,500,1000,100,350,2000,1250]
}
df = pd.DataFrame(data)
print(" total sales for each product category:")
print(df.groupby("category")["sale"].sum())
# Out:
#  total sales for each product category:
# category
# B1    1450
# B2     850
# B3    3000
# B4     100
# Name: sale, dtype: int64

# %% [markdown]
# **Problem 9:** Create a line chart using Matplotlib to visualize the population growth of a city over 10 years. Label the axes and provide a title.

# %%
import numpy as np
import matplotlib.pyplot as plt

year = [2014 , 2015 , 2016 , 2017 , 2018 , 2019 , 2020, 2021 , 2022 , 2023]
population = [1 , 1.2 , 1.4, 1.8, 1.8, 2, 2.1, 1.9, 1.8, 2.3]
plt.plot(year , population , marker = ".")
plt.xlabel("year")
plt.ylabel("population(*10^6)")
plt.title("the population growth of a city over 10 years")
# Out:
# Text(0.5, 1.0, 'the population growth of a city over 10 years')

# %% [markdown]
# **Problem 10:** Given a Pandas DataFrame containing information about students, add a new column 'Grade' based on the following criteria:
# * If 'Score' >= 90, Grade is 'A'
# * If 'Score' >= 80, Grade is 'B'
# * If 'Score' >= 70, Grade is 'C'
# * If 'Score' < 70, Grade is 'D'

# %%
import pandas as pd
data = {
    "Name":["Amir","Ali","Sara","Leyla"],
    "Score":[100,50,85,75]
}
df = pd.DataFrame(data)
grades = []
for score in df['Score']:
    if score >= 90:
        grades.append('A')
    elif score >= 80:
        grades.append('B')
    elif score >= 70:
        grades.append('C')
    else:
        grades.append('D')

df['Grade'] = grades

print(df)
# Out:
#     Name  Score Grade
# 0   Amir    100     A
# 1    Ali     50     D
# 2   Sara     85     B
# 3  Leyla     75     C

# %% [markdown]
# **Problem 11:** You are given a dataset containing monthly sales data for three products (A, B, and C) over a two-year period. Your task is to perform various data analysis tasks using NumPy, Pandas, and Matplotlib.
#
#
# *   Dataset:
#
# ```
# import pandas as pd
#
# data = {
#     'Month': pd.date_range(start='2021-01-01', periods=24, freq='M'),
#     'Product A Sales': [500, 480, 600, 750, 900, 850, 920, 1100, 1300, 1350, 1500, 1450, 1550, 1600, 1650, 1600, 1500, 1400, 1600, 1700, 1800, 1750, 1850, 1900],
#     'Product B Sales': [300, 320, 400, 450, 500, 580, 700, 750, 820, 900, 950, 980, 1050, 1100, 1150, 1200, 1250, 1300, 1350, 1400, 1500, 1600, 1550, 1700],
#     'Product C Sales': [200, 210, 250, 280, 320, 350, 380, 400, 420, 440, 460, 480, 500, 520, 540, 560, 580, 600, 620, 640, 660, 680, 700, 720]
# }
#
# sales_df = pd.DataFrame(data)
# ```
# *  Tasks:
# 1. Calculate and display the total sales for each product over the two-year period.
#
# 2. Calculate and display the average monthly sales for each product.
#
# 3. Find the month with the highest sales for each product, and display the product and the sales value for that month.
#
# 4. Calculate and display the percentage change in sales for each product from January to December in the second year (2022).
#
# 5. Create a line chart using Matplotlib to visualize the monthly sales data for each product over the two-year period. Label the axes and provide a title for the chart.
#
# 6. Calculate the correlation between Product A and Product B sales. Is there a strong correlation between these two products? Display the correlation coefficient.

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'Month': pd.date_range(start='2021-01-01', periods=24, freq='M'),
    'Product A Sales': [500, 480, 600, 750, 900, 850, 920, 1100, 1300, 1350, 1500, 1450, 1550, 1600, 1650, 1600, 1500, 1400, 1600, 1700, 1800, 1750, 1850, 1900],
    'Product B Sales': [300, 320, 400, 450, 500, 580, 700, 750, 820, 900, 950, 980, 1050, 1100, 1150, 1200, 1250, 1300, 1350, 1400, 1500, 1600, 1550, 1700],
    'Product C Sales': [200, 210, 250, 280, 320, 350, 380, 400, 420, 440, 460, 480, 500, 520, 540, 560, 580, 600, 620, 640, 660, 680, 700, 720]
}

sales_df = pd.DataFrame(data)
# task 1
print("task 1:")
print(sales_df.sum())
# task 2
print("task 2:")
print("average monthly sales for each product:")
print(sales_df.mean())
# task 3
print("task 3:")
print("month with the highest sales for each product")
print(sales_df.max())
print(sales_df.idxmax())

# task 4
print("task 4:")
sales_2021 = sales_df.loc[0:11][['Product A Sales', 'Product B Sales', 'Product C Sales']].sum()
sales_2022 = sales_df.loc[12:23][['Product A Sales', 'Product B Sales', 'Product C Sales']].sum()
percentage_change = ((sales_2022 - sales_2021) / sales_2021) * 100
print("\nPercentage Change in Sales from January to December in 2022:")
print(percentage_change)
# task 5

print("task 5:")
X = sales_df['Month']
Y1 = sales_df['Product A Sales']
Y2 = sales_df['Product B Sales']
Y3 = sales_df['Product C Sales']

plt.plot(X , Y1 , marker = '1' , label = "product A")
plt.plot(X , Y2 , marker = "2", label = "product B")
plt.plot(X , Y3 , marker = "3", label = "product C")

plt.xlabel("month")
plt.ylabel("sales")
plt.legend()
plt.title("the monthly sales data for each product over the two-year period")

# task 6
print("task 6:")
correlation_coefficient = sales_df['Product A Sales'].corr(sales_df['Product B Sales'])
print(correlation_coefficient)
# Out:
# task 1:
# Product A Sales    31600
# Product B Sales    23800
# Product C Sales    11510
# dtype: int64
# task 2:
# average monthly sales for each product:
# Product A Sales    1316.666667
# Product B Sales     991.666667
# Product C Sales     479.583333
# dtype: float64
# task 3:
# month with the highest sales for each product
# Month              2022-12-31 00:00:00
# Product A Sales                   1900
# Product B Sales                   1700
# Product C Sales                    720
# dtype: object
# Month              23
# Product A Sales    23
# Product B Sales    23
# Product C Sales    23
# dtype: int64
# task 4:
#
# Percentage Change in Sales from January to December in 2022:
# Product A Sales     70.085470
# Product B Sales    111.111111
# Product C Sales     74.701671
# dtype: float64
# task 5:
# task 6:
# 0.954652710589704
# <ipython-input-54-182e270c98db>:14: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(sales_df.sum())
# <ipython-input-54-182e270c98db>:18: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   print(sales_df.mean())
