# %% [markdown]
# <a href="https://colab.research.google.com/github/amirjhn/MachineLearning2025/blob/main/mini%20project%202/mini_project_2_q2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import itertools

# %% [markdown]
# ![CamScanner 12-16-2023 15.20.jpg](data:image/jpeg;base64,...)

# %%
class McCulloch_Pitts_neuron():

  def __init__(self , weights , threshold):
    self.weights = weights
    self.threshold = threshold

  def model(self , x):
    if self.weights @ x >= self.threshold:
        return 1
    else:
        return 0

# %%
def XNOR(input):
  neur1 = McCulloch_Pitts_neuron([1, 1], 1.5)
  neur2 = McCulloch_Pitts_neuron([-1, -1], -0.5)
  neur3 = McCulloch_Pitts_neuron([1, 1], 1)

  z1 = neur1.model(np.array([input[0], input[1]]))
  z2 = neur2.model(np.array([input[0], input[1]]))
  z3 = neur3.model(np.array([z1, z2]))


  return list([z1, z2, z3])

# %%
input = [1, 0]
X = list(itertools.product(input, input))

for i in X:
    res = XNOR(i)
    print("XNOR with input as", str(i[0]) + str(" ")+str(i[1]), "goes to output ", str(res[2]))
# Out:
# XNOR with input as 1 1 goes to output  1
# XNOR with input as 1 0 goes to output  0
# XNOR with input as 0 1 goes to output  0
# XNOR with input as 0 0 goes to output  1
